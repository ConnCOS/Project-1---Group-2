# %%
import requests
import json

from geoapify_key import geoapify_key

commercial_url = f"https://api.geoapify.com/v2/places?categories=commercial.outdoor_and_sport&filter=place:516e5b30b70d635ac059a83f79facf7f4340f00101f901a978020000000000920308436f6c6f7261646f&limit=20&apiKey=7eb929716fdc4062aa57cdd747fd6629"
rental_url = f"https://api.geoapify.com/v2/places?categories=commercial.outdoor_and_sport&filter=place:516e5b30b70d635ac059a83f79facf7f4340f00101f901a978020000000000920308436f6c6f7261646f&limit=20&apiKey=7eb929716fdc4062aa57cdd747fd6629"

# %%
commercial_data = requests.get(commercial_url).json()
print(commercial_data)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'REI', 'country': 'United States', 'country_code': 'us', 'state': 'Colorado', 'county': 'El Paso County', 'city': 'Colorado Springs', 'postcode': '80920', 'street': 'East Woodmen Road', 'housenumber': '1376', 'lon': -104.79976213072894, 'lat': 38.9338309, 'state_code': 'CO', 'formatted': 'REI, 1376 East Woodmen Road, Colorado Springs, CO 80920, United States of America', 'address_line1': 'REI', 'address_line2': '1376 East Woodmen Road, Colorado Springs, CO 80920, United States of America', 'categories': ['building', 'building.commercial', 'commercial', 'commercial.outdoor_and_sport'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'REI', 'shop': 'outdoor', 'brand': 'REI', 'phone': '+1-719-260-1455', 'osm_id': 21
# ...

# %%
rental_data = requests.get(rental_url).json()
print(rental_data)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'REI', 'country': 'United States', 'country_code': 'us', 'state': 'Colorado', 'county': 'El Paso County', 'city': 'Colorado Springs', 'postcode': '80920', 'street': 'East Woodmen Road', 'housenumber': '1376', 'lon': -104.79976213072894, 'lat': 38.9338309, 'state_code': 'CO', 'formatted': 'REI, 1376 East Woodmen Road, Colorado Springs, CO 80920, United States of America', 'address_line1': 'REI', 'address_line2': '1376 East Woodmen Road, Colorado Springs, CO 80920, United States of America', 'categories': ['building', 'building.commercial', 'commercial', 'commercial.outdoor_and_sport'], 'details': ['details', 'details.contact'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'REI', 'shop': 'outdoor', 'brand': 'REI', 'phone': '+1-719-260-1455', 'osm_id': 21
# ...
