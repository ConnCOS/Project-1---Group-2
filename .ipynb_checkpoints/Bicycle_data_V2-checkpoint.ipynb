# %%
# dependencies
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
#importing file path
#file path = "Bicycle_and_Pedestrian_Counts_in_Colorado (1).csv"
bike_data_to_load = Path("/Bicycle_and_Pedestrian_Counts_in_Colorado (1).csv")

# %%
#store as a dataframe
bike_data_to_load = pd.read_csv(bike_data_to_load)
bike_data_to_load.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 #store as a dataframe
# ----> 2 bike_data_to_load = pd.read_csv(bike_data_to_load)
#       3 bike_data_to_load.head()
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~\anaconda3\Lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Resources\\Bicycle_and_Pedestrian_Counts_in_Colorado (1).csv'

# %%
#Get list of data columns
list (bike_data_to_load.columns)
# Out:
# ['stationId',
#  'dataCollected',
#  'county',
#  'location',
#  'lat',
#  'long',
#  'direction',
#  'month',
#  'year',
#  'dataDate',
#  'dayOfWeek',
#  'hr00',
#  'hr01',
#  'hr02',
#  'hr03',
#  'hr04',
#  'hr05',
#  'hr06',
#  'hr07',
#  'hr08',
#  'hr09',
#  'hr10',
#  'hr11',
#  'hr12',
#  'hr13',
#  'hr14',
#  'hr15',
#  'hr16',
#  'hr17',
#  'hr18',
#  'hr19',
#  'hr20',
#  'hr21',
#  'hr22',
#  'hr23',
#  'Location 1',
#  'Counties']

# %%
Bicycle_reduced = bike_data_to_load[['stationId', 'dataCollected', 'county', 'location', 'lat',
'long',
'month',
'year',
'dataDate',
'dayOfWeek', 'hr00',
 'hr01',
 'hr02',
 'hr03',
 'hr04',
 'hr05',
 'hr06',
 'hr07',
 'hr08',
 'hr09',
 'hr10',
 'hr11',
 'hr12',
 'hr13',
 'hr14',
 'hr15',
 'hr16',
 'hr17',
 'hr18',
 'hr19',
 'hr20',
 'hr21',
 'hr22',
 'hr23',
'Location 1']]
Bicycle_reduced.head()
# Out:
#   stationId      dataCollected  county  \
# 0    B9012B               BIKE  Pueblo
# 1    B9012B               BIKE  Pueblo
# 2    B00050  BIKE & PEDESTRIAN    Weld
# 3    B00049  BIKE & PEDESTRIAN   Adams
# 4    B00049  BIKE & PEDESTRIAN   Adams
#
#                                  location        lat        long  month  year  \
# 0                  Memorial Dr, Lamar, CO  38.071995 -102.615190      5  2014
# 1                  Memorial Dr, Lamar, CO  38.071995 -102.615190     10  2013
# 2  Greeley (Pouder River Trail at SH 257)  40.444467 -104.883688     10  2012
# 3        SOUTH PLATTE RIVER AT 74TH/YORK   39.826853 -104.949692      9  2012
# 4        SOUTH PLATTE RIVER AT 74TH/YORK   39.826853 -104.949692      9  2012
#
#                  dataDate  dayOfWeek  ...  hr15  hr16  hr17  hr18  hr19  hr20  \
# 0  05/18/2014 12:00:00 AM          1  ...     0     2     2     0     0     0
# 1  10/28/2013 12:00:00 AM          2  ...     0     1     2     0     0     0
# 2  10/25/2012 12:00:00 AM          5  ...     3     1     1     0     0     0
# 3  09/29/2012 12:00:00 AM          7  ...    17    17    14     4     0     3
# 4  09/21/2012 12:00:00 AM          6  ...    18    22    29     6     3     2
#
#    hr21  hr22  hr23                  Location 1
# 0     0     0     0     (38.071995, -102.61519)
# 1     0     0     0     (38.071995, -102.61519)
# 2     0     0     0   (40.4444673, -104.883688)
# 3     1     0     0  (39.82685334, -104.949692)
# 4     0     1     0  (39.82685334, -104.949692)
#
# [5 rows x 35 columns]

# %%
#Drop all rows with missing information
Bicycle_reduced = Bicycle_reduced.dropna(how = "any")

# %%
#Verify dropped rows
Bicycle_reduced.count()
# Out:
# stationId        61489
# dataCollected    61489
# county           61489
# location         61489
# lat              61489
# long             61489
# month            61489
# year             61489
# dataDate         61489
# dayOfWeek        61489
# hr00             61489
# hr01             61489
# hr02             61489
# hr03             61489
# hr04             61489
# hr05             61489
# hr06             61489
# hr07             61489
# hr08             61489
# hr09             61489
# hr10             61489
# hr11             61489
# hr12             61489
# hr13             61489
# hr14             61489
# hr15             61489
# hr16             61489
# hr17             61489
# hr18             61489
# hr19             61489
# hr20             61489
# hr21             61489
# hr22             61489
# hr23             61489
# Location 1       61489
# dtype: int64

# %%
#Rename columns
Bicycle_reduced.rename(columns = {"stationId":"Station ID",
                                        "dataCollected" : "Data Collected",
                                        "county" : "County", 
                                        "location" : "Location",
                                        "lat" : "Lat",
                                        "long" : "Long",
                                        "month" : "Month",
                                        "year" : "Year",
                                        "dataDate" : "Data Date",
                                        "dayOfWeek" : "Day of Week",
                                        "hr00" : "Hr00", "hr01" : "Hr01", "hr02" : "Hr02",
                                        "hr03" : "Hr03", "hr04": "Hr04" , "hr05" : "Hr05", "hr06": "Hr06", "hr07" : "Hr07",
                                        "hr08" : "Hr08", "hr09" : "Hr09", "hr10" : "Hr10", "hr11" : "Hr11", "hr12" : "Hr12", "hr13": "Hr13",
                                        "h14" : "Hr14", "hr15" : "Hr15", "hr16" : "Hr16", "hr17" : "Hr17", "hr18" : "Hr18", "hr19" : "Hr19",
                                        "hr20" : "Hr20", "hr21" : "Hr21", "hr22" : "Hr22", "hr23" : "Hr23"}, inplace = True,)
Bicycle_reduced.head()
# Out:
#   Station ID     Data Collected  County  \
# 0     B9012B               BIKE  Pueblo
# 1     B9012B               BIKE  Pueblo
# 2     B00050  BIKE & PEDESTRIAN    Weld
# 3     B00049  BIKE & PEDESTRIAN   Adams
# 4     B00049  BIKE & PEDESTRIAN   Adams
#
#                                  Location        Lat        Long  Month  Year  \
# 0                  Memorial Dr, Lamar, CO  38.071995 -102.615190      5  2014
# 1                  Memorial Dr, Lamar, CO  38.071995 -102.615190     10  2013
# 2  Greeley (Pouder River Trail at SH 257)  40.444467 -104.883688     10  2012
# 3        SOUTH PLATTE RIVER AT 74TH/YORK   39.826853 -104.949692      9  2012
# 4        SOUTH PLATTE RIVER AT 74TH/YORK   39.826853 -104.949692      9  2012
#
#                 Data Date  Day of Week  ...  Hr15  Hr16  Hr17  Hr18  Hr19  \
# 0  05/18/2014 12:00:00 AM            1  ...     0     2     2     0     0
# 1  10/28/2013 12:00:00 AM            2  ...     0     1     2     0     0
# 2  10/25/2012 12:00:00 AM            5  ...     3     1     1     0     0
# 3  09/29/2012 12:00:00 AM            7  ...    17    17    14     4     0
# 4  09/21/2012 12:00:00 AM            6  ...    18    22    29     6     3
#
#    Hr20  Hr21  Hr22  Hr23                  Location 1
# 0     0     0     0     0     (38.071995, -102.61519)
# 1     0     0     0     0     (38.071995, -102.61519)
# 2     0     0     0     0   (40.4444673, -104.883688)
# 3     3     1     0     0  (39.82685334, -104.949692)
# 4     2     0     1     0  (39.82685334, -104.949692)
#
# [5 rows x 35 columns]

# %%
# Replace values within Data Collected column
Bicycle_reduced["Data Collected"] = Bicycle_reduced["Data Collected"].replace({'BIKE&PED':'BIKE & PEDESTRIAN', 'PED':'PEDESTRIAN'})

# %%
# Verify unique values within Data colected column
Bicycle_reduced["Data Collected"].unique()
# Out:
# array(['BIKE', 'BIKE & PEDESTRIAN', 'PEDESTRIAN'], dtype=object)

# %%
#Verify counties
Bicycle_reduced["County"].unique()
# Out:
# array(['Pueblo', 'Weld', 'Adams', 'Denver', 'Jefferson', 'Larimer',
#        'Summit', 'Douglas', 'Eagle', 'Boulder', 'Arapahoe', 'Mesa',
#        'El Paso', 'La Plata', 'Routt', 'Garfield', 'Broomfield',
#        'Montrose', 'Teller', 'Clear Creek'], dtype=object)

# %%
#Verify number of years
Bicycle_reduced["Year"].unique()
# Out:
# array([2014, 2013, 2012, 2015, 2011, 2009, 2010])

# %%
Bicycle_reduced.dtypes
# Out:
# Station ID         object
# Data Collected     object
# County             object
# Location           object
# Lat               float64
# Long              float64
# Month               int64
# Year                int64
# Data Date          object
# Day of Week         int64
# Hr00                int64
# Hr01                int64
# Hr02                int64
# Hr03                int64
# Hr04                int64
# Hr05                int64
# Hr06                int64
# Hr07                int64
# Hr08                int64
# Hr09                int64
# Hr10                int64
# Hr11                int64
# Hr12                int64
# Hr13                int64
# hr14                int64
# Hr15                int64
# Hr16                int64
# Hr17                int64
# Hr18                int64
# Hr19                int64
# Hr20                int64
# Hr21                int64
# Hr22                int64
# Hr23                int64
# Location 1         object
# dtype: object

# %%
#Group hours into single days for each county
County_count = Bicycle_reduced[(Bicycle_reduced["Hr00": "Hr23"]).sum()["County"]]
County_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 #Group hours into single days for each county
# ----> 2 County_count = Bicycle_reduced[(Bicycle_reduced["Hr00": "Hr23"]).sum()["County"]]
#       3 County_count
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:3779, in DataFrame.__getitem__(self, key)
#    3777         return self._getitem_multilevel(key)
#    3778 # Do we have a slicer (on rows)?
# -> 3779 indexer = convert_to_index_sliceable(self, key)
#    3780 if indexer is not None:
#    3781     if isinstance(indexer, np.ndarray):
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexing.py:2494, in convert_to_index_sliceable(obj, key)
#    2492 idx = obj.index
#    2493 if isinstance(key, slice):
# -> 2494     return idx._convert_slice_indexer(key, kind="getitem")
#    2496 elif isinstance(key, str):
#    2497
#    2498     # we are an actual column
#    2499     if key in obj.columns:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/numeric.py:234, in NumericIndex._convert_slice_indexer(self, key, kind)
#     228     # TODO: can we write this as a condition based on
#     229     #  e.g. _should_fallback_to_positional?
#     230     # We always treat __getitem__ slicing as label-based
#     231     # translate to locations
#     232     return self.slice_indexer(key.start, key.stop, key.step)
# --> 234 return super()._convert_slice_indexer(key, kind=kind)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:4250, in Index._convert_slice_indexer(self, key, kind)
#    4246 if kind == "getitem":
#    4247     # called from the getitem slicers, validate that we are in fact integers
#    4248     if self.is_integer() or is_index_slice:
#    4249         # Note: these checks are redundant if we know is_index_slice
# -> 4250         self._validate_indexer("slice", key.start, "getitem")
#    4251         self._validate_indexer("slice", key.stop, "getitem")
#    4252         self._validate_indexer("slice", key.step, "getitem")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/indexes/base.py:6591, in Index._validate_indexer(self, form, key, kind)
#    6588 assert kind in ["getitem", "iloc"]
#    6590 if key is not None and not is_integer(key):
# -> 6591     raise self._invalid_indexer(form, key)
#
# TypeError: cannot do slice indexing on Int64Index with these indexers [Hr00] of type str
